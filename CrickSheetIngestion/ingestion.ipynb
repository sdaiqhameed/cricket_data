# %%
import json
import pandas as pd
from datetime import datetime
import glob

# %%
# %run "DAL.ipynb"

# %%
def abbreviate(string):
    words = string.split()
    abbr = ''.join(word[0].upper() for word in words)
    return abbr

# %%
class CricketFileProcessor:
    def __init__(self):

        self.meta = None
        self.info = None
        self.innings = None

        self.event = None
        self.event_name = ""
        self.eventID = ""

        self.venue = None
        self.venueID = ""

        self.dates = None
        self.mdate = ""
        self.teams = None
        self.team1ID = ""
        self.team2ID = ""
        self.matchID = ""

        self.peopleDF = pd.DataFrame()
        self.eventDF = pd.DataFrame()

    # initialize IDs 
    def InitializeIDs(self):
        self.event = self.info["event"]
        self.event_name = abbreviate(self.event["name"])
        self.eventID = self.event_name + self.info["season"]

        self.venue = self.info["venue"]
        self.vanueID = abbreviate(self.venue)

        self.dates = self.info["dates"]
        self.mdate = datetime.strptime(self.dates[0], "%Y-%m-%d")
        self.teams = self.info["teams"]
        self.team1ID = abbreviate(self.teams[0])
        self.team2ID = abbreviate(self.teams[1])
        self.matchID = self.event_name + self.mdate.strftime("%Y%m%d")+ self.team1ID + self.team2ID


        # people DF 
    def calculatePeopleDF(self):
        people = self.info["registry"]["people"] 
        people_list = [] 
        for key, value in people.items():
            p = {"ID": value, "name": key}
            people_list.append(p)
        self.peopleDF = pd.DataFrame(people_list)

    def getPeopleID(self, name):
        row = self.peopleDF.loc[self.peopleDF['name'] == name]
        return row.iloc[0]['ID']

    def savePeopleDFinSQL(self):
        for row in self.peopleDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdatePeople] '{row[1]["ID"]}', '{row[1]["name"]}'"
            DAL.getInstance().execute_query(SQL)

    # Event DF 
    def calculateEventDF(self):
        event_list = {
            
            'eventID': self.eventID, 
            'event_name': self.event["name"],
            'season': self.info["season"]
        }
        self.eventDF = pd.DataFrame(event_list, index=[0])
    def saveEventDFinSQL(self):
        for row in self.eventDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateEvent] '{row[1]["eventID"]}', '{row[1]["event_name"]}', '{row[1]["season"]}'"
            DAL.getInstance().execute_query(SQL)

    def calculateVenueDF(self):
        venue_list = {
            'venueID': self.venueID,
            'venue': self.venue
        }
        self.venueDF = pd.DataFrame(venue_list, index=[0])
    def saveVenueDFinSQL(self):
        for row in self.venueDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateVenue] '{row[1]["venueID"]}', '{row[1]["venue"]}'"
            DAL.getInstance().execute_query(SQL)

    def calculateTeamDF(self):
        team_list = {
            'teamID': [self.team1ID, self.team2ID], 
            'team': [self.teams[0], self.teams[1]], 
            'gender': [self.info["gender"], self.info["gender"]], 
            'team_type': [self.info["team_type"], self.info["team_type"]]
        }
        self.teamDF = pd.DataFrame(team_list, index=[0,1])
    def saveTeamDFinSQL(self):
        for row in self.teamDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateTeams] '{row[1]["teamID"]}', '{row[1]["team"]}', '{row[1]["gender"]}', '{row[1]["team_type"]}'"
            DAL.getInstance().execute_query(SQL)

    def calculateMatchPlayersDF(self):
        playersteam1 = self.info["players"][self.teams[0]]
        playersteam2 = self.info["players"][self.teams[1]]
        player_list = []

        for player in playersteam1:
            playerID = self.getPeopleID(player)
            p = {"matchID": self.matchID, "teamID": self.team1ID, "playerID": playerID}
            player_list.append(p)
        for player in playersteam2:
            playerID = self.getPeopleID(player)
            p = {"matchID": self.matchID, "teamID": self.team2ID, "playerID": playerID}
            player_list.append(p)
        self.playerDF = pd.DataFrame(player_list)
    def savePlayerDFinSQL(self):
        for row in self.playerDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateMatchPlayers] '{row[1]["matchID"]}', '{row[1]["teamID"]}', '{row[1]["playerID"]}'"
            DAL.getInstance().execute_query(SQL)
        
    def calculateInningsDF(self):
        inning_list = []
        over_list= []
        inningID = 0 

        for inning in self.innings:
            inningID += 1
            teamID = abbreviate(inning["team"])
            i = {"matchID": self.matchID, "inning": inningID, "team": teamID}
            inning_list.append(i)
            overs = inning["overs"]
            for over in overs:
                over_number = over["over"]
                deliveries = over["deliveries"]
                ball = 0 
                for delivery in deliveries:
                    ball += 1
                    batter = self.getPeopleID(delivery["batter"])
                    bowler = self.getPeopleID(delivery["bowler"])
                    non_striker = self.getPeopleID(delivery["non_striker"])
                    extra_type = "" 
                    extra_runs = 0 
                    if 'extras' in delivery:
                        for key, value in delivery["extras"].items():
                            extra_type = key 
                            extra_runs = value
                    batter_run = 0
                    total_run = 0
                    if 'runs' in delivery:
                        batter_run = delivery["runs"]["batter"]
                        total_run = delivery["runs"]["total"]
                    wicket_kind = "NONE"
                    player_out = "NONE"
                    fielder = "NONE"
                    if 'wickets' in delivery:
                        wicket_kind = delivery["wickets"][0]["kind"]
                        player_out = self.getPeopleID(delivery["wickets"][0]["player_out"])
                        if 'fielders' in delivery:
                            fielder = self.getPeopleID(delivery["wickets"][0]["fielders"][0]["name"])

                    b = {"matchID": self.matchID, "inning": str(inningID), "over": str(over_number), "ball": ball, "batter": batter, "bowler": bowler, 
                        "non_striker": non_striker, "batter_run": str(batter_run), "extra_run": str(extra_runs), "extra_type": extra_type, "total_run": str(total_run),
                        "wicket_kind": wicket_kind, "player_out": player_out, "fielder": fielder}
                    over_list.append(b)
        self.inningDF = pd.DataFrame(inning_list)
        self.overDF = pd.DataFrame(over_list)
    def saveInningDFinSQL(self):
        for row in self.inningDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateInning] '{row[1]["matchID"]}', '{row[1]["inning"]}', '{row[1]["team"]}'"
            DAL.getInstance().execute_query(SQL)
    def saveOverDFinSQL(self):
        for row in self.overDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateOver] '{row[1]["matchID"]}', '{row[1]["inning"]}', '{row[1]["over"]}', '{row[1]["ball"]}', '{row[1]["batter"]}', '{row[1]["bowler"]}', '{row[1]["non_striker"]}', '{row[1]["batter_run"]}', '{row[1]["extra_run"]}', '{row[1]["extra_type"]}', '{row[1]["total_run"]}', '{row[1]["wicket_kind"]}', '{row[1]["player_out"]}', '{row[1]["fielder"]}'"
            DAL.getInstance().execute_query(SQL)

    def calculateMatchDF(self):
        city = "" 
        if 'city' in self.info:
            city = self.info["city"]

        match_number = "" 
        if 'match_number' in self.info:
            match_number = self.info["event"]["match_number"]

        toss = self.info["toss"]
        outcome = self.info["outcome"] 
        winner = ""
        result = ""
        by = ""
        if 'result' in outcome: 
            result = outcome["result"]
        if 'winner' in outcome: 
            winner = abbreviate( outcome["winner"])
            result = outcome["winner"] + " wins"
            dby = outcome["by"]
            if "wickets" in dby:
                by = str(dby["wickets"]) + " wickets"
            elif 'runs' in dby:
                by = str(dby["runs"]) + " runs"



        reserve_umpire = ""
        match_referee = "" 
        tv_umpire = "" 
        umpire1 = "" 
        umpire2 = "" 

        officials = self.info["officials"]
        if 'reserve_umpires' in officials:
            reserve_umpires = officials["reserve_umpires"]
            reserve_umpire = self.getPeopleID(reserve_umpires[0])
        if 'match_referees' in officials:
            match_referees = officials["match_referees"]
            match_referee = self.getPeopleID( match_referees[0])
        if 'tv_umpires' in officials:
            tv_umpires = officials["tv_umpires"]
            tv_umpire = self.getPeopleID(tv_umpires[0])
        if 'umpires' in officials:
            umpires = officials["umpires"]
            umpire1 = self.getPeopleID(umpires[0])
            umpire2 = self.getPeopleID(umpires[1])


        match = {
                'matchID': self.matchID,
                'eventID': self.eventID, 
                'venueID': self.vanueID,
                'meta_version': self.meta["data_version"],
                'meta_created': self.meta["created"], 
                'revision': self.meta["revision"],
                'balls_per_over': self.info["balls_per_over"],
                'match_number': match_number, 
                'city': city, 
                'start_date': self.dates[0], 
                'gender': self.info["gender"],
                'match_type': self.info["match_type"],
                'toss_winner' : abbreviate( toss["winner"]), 
                'toss_decision': toss["decision"], 
                'overs': self.info["overs"],
                'result': result, 
                'winner': winner, 
                'win_by': by,
                'reserve_umpire':  reserve_umpire,
                'match_referee': match_referee, 
                'tv_umpire': tv_umpire, 
                'umpire1': umpire1, 
                'umpire2': umpire2,
                'team_type': self.info["team_type"]
                }

        # Create DataFrame
        self.matchDF = pd.DataFrame(match, index=[0])
    def saveMatchDFinSQL(self):
        for row in self.matchDF.iterrows():
            SQL = f"EXEC [dbo].[AddUpdateMatch] '{row[1]["matchID"]}', '{row[1]["eventID"]}', '{row[1]["venueID"]}', '{row[1]["meta_version"]}','{row[1]["meta_created"]}', '{row[1]["revision"]}', '{row[1]["balls_per_over"]}', '{row[1]["match_number"]}', '{row[1]["city"]}','{row[1]["start_date"]}', '{row[1]["gender"]}', '{row[1]["match_type"]}', '{row[1]["toss_winner"]}', '{row[1]["toss_decision"]}','{row[1]["overs"]}','{row[1]["result"]}','{row[1]["winner"]}','{row[1]["win_by"]}','{row[1]["reserve_umpire"]}','{row[1]["match_referee"]}','{row[1]["tv_umpire"]}','{row[1]["umpire1"]}','{row[1]["umpire2"]}','{row[1]["team_type"]}'"
            DAL.getInstance().execute_query(SQL)


    def processCricketFile(self, filename):
        # Open the JSON file
        #with open('../PSL/match.json', 'r') as f:
        with open(filename, 'r') as f:
            # Load the JSON data into a Python dictionary
            self.data = json.load(f)

        self.meta = self.data["meta"]
        self.info = self.data["info"]
        self.innings = self.data["innings"]

        self.InitializeIDs()
        self.calculatePeopleDF()
        self.calculateEventDF()
        self.calculateVenueDF()
        self.calculateTeamDF()
        self.calculateMatchPlayersDF()
        self.calculateInningsDF()
        self.calculateMatchDF() 

        self.savePeopleDFinSQL()
        self.saveEventDFinSQL()
        self.saveVenueDFinSQL()
        self.saveTeamDFinSQL()
        self.savePlayerDFinSQL()
        self.saveInningDFinSQL()
        self.saveOverDFinSQL()
        self.saveMatchDFinSQL()

        print(f"Save match file ({filename})... {self.matchID}")

# %%
def listAllCricketFilePaths():
    file_paths = glob.glob('C:\\work\\cricket\\PSL\\*')
    PATHS = []
    for file_path in file_paths:
        if '.json' not in file_path:
            file_paths_inner = glob.glob(file_path + '\\*')
            #print(file_paths_inner)
            for file_path_inner in file_paths_inner:
                if '.json' in str(file_path_inner):
                    PATHS.append(str(file_path_inner))
        else:
            if '.json' in str(file_path):
                PATHS.append(str(file_path))
    return PATHS

# %%
def processAllCricketFiles():
    file_paths = listAllCricketFilePaths()

    cfp = CricketFileProcessor() 
    for file in file_paths:
        cfp.processCricketFile(file)
        #break

# %%
processAllCricketFiles()
# Out:
# Save match file (C:\work\cricket\PSL\1075986.json)... PSL20170209IUPZ
# Save match file (C:\work\cricket\PSL\1075987.json)... PSL20170210LQQG
# Save match file (C:\work\cricket\PSL\1075988.json)... PSL20170210KKPZ
# Save match file (C:\work\cricket\PSL\1075989.json)... PSL20170211IULQ
# Save match file (C:\work\cricket\PSL\1075990.json)... PSL20170211KKQG
# Save match file (C:\work\cricket\PSL\1075991.json)... PSL20170212LQPZ
# Save match file (C:\work\cricket\PSL\1075992.json)... PSL20170215IUQG
# Save match file (C:\work\cricket\PSL\1075993.json)... PSL20170216KKLQ
# Save match file (C:\work\cricket\PSL\1075994.json)... PSL20170217PZQG
# Save match file (C:\work\cricket\PSL\1075995.json)... PSL20170217IUKK
# Save match file (C:\work\cricket\PSL\1075996.json)... PSL20170218LQQG
# Save match file (C:\work\cricket\PSL\1075997.json)... PSL20170218IUPZ
# Save match file (C:\work\cricket\PSL\1075998.json)... PSL20170219KKPZ
# Save match file (C:\work\cricket\PSL\1075999.json)... PSL20170220IULQ
# Save match file (C:\work\cricket\PSL\1076000.json)... PSL20170223KKQG
# Save match file (C:\work\cricket\PSL\1076001.json)... PSL20170224LQPZ
# Save match file (C:\work\cricket\PSL\1076002.json)... PSL20170224IUQG
# Save match file (C:\work\cricket\PSL\1076003.json)... PSL20170225KKLQ
# Save match file (C:\work\cricket\PSL\1076004.json)... PSL20170225PZQG
# Save match file (C:\work\cricket\PSL\1076005.json)... PSL20170226IUKK
# Save match file (C:\work\cricket\PSL\1076006.json)... PSL20170228QGPZ
# Save match file (C:\work\cricket\PSL\1076007.json)... PSL20170301KKIU
# Save match file (C:\work\cricket\PSL\1076008.json)... PSL20170303PZKK
# Save match file (C:\work\cricket\PSL\1076009.json)... PSL20170305PZQG
# Save match file (C:\work\cricket\PSL\1128818.json)... PSL20180222PZMS
# Save match file (C:\work\cricket\PSL\1128819.json)... PSL20180223KKQG
# Save match file (C:\work\cricket\PSL\1128820.json)... PSL20180223MSLQ
# Save match file (C:\work\cricket\PSL\1128821.json)... PSL20180224IUPZ
# Save match file (C:\work\cricket\PSL\1128822.json)... PSL20180224QGLQ
# Save match file (C:\work\cricket\PSL\1128823.json)... PSL20180225MSIU
# Save match file (C:\work\cricket\PSL\1128824.json)... PSL20180225KKPZ
# Save match file (C:\work\cricket\PSL\1128825.json)... PSL20180226KKLQ
# Save match file (C:\work\cricket\PSL\1128826.json)... PSL20180228IUQG
# Save match file (C:\work\cricket\PSL\1128827.json)... PSL20180301QGPZ
# Save match file (C:\work\cricket\PSL\1128829.json)... PSL20180302LQIU
# Save match file (C:\work\cricket\PSL\1128830.json)... PSL20180303MSQG
# Save match file (C:\work\cricket\PSL\1128831.json)... PSL20180303PZLQ
# Save match file (C:\work\cricket\PSL\1128832.json)... PSL20180304IUKK
# Save match file (C:\work\cricket\PSL\1128833.json)... PSL20180306PZMS
# Save match file (C:\work\cricket\PSL\1128834.json)... PSL20180307MSQG
# Save match file (C:\work\cricket\PSL\1128835.json)... PSL20180308IULQ
# Save match file (C:\work\cricket\PSL\1128836.json)... PSL20180308KKQG
# Save match file (C:\work\cricket\PSL\1128837.json)... PSL20180309MSLQ
# Save match file (C:\work\cricket\PSL\1128838.json)... PSL20180309PZIU
# Save match file (C:\work\cricket\PSL\1128839.json)... PSL20180310MSKK
# Save match file (C:\work\cricket\PSL\1128840.json)... PSL20180310PZQG
# Save match file (C:\work\cricket\PSL\1128841.json)... PSL20180311KKLQ
# Save match file (C:\work\cricket\PSL\1128842.json)... PSL20180313MSIU
# Save match file (C:\work\cricket\PSL\1128843.json)... PSL20180314QGLQ
# Save match file (C:\work\cricket\PSL\1128844.json)... PSL20180315PZKK
# Save match file (C:\work\cricket\PSL\1128845.json)... PSL20180315QGIU
# Save match file (C:\work\cricket\PSL\1128846.json)... PSL20180316PZLQ
# Save match file (C:\work\cricket\PSL\1128847.json)... PSL20180316IUKK
# Save match file (C:\work\cricket\PSL\1128848.json)... PSL20180318IUKK
# Save match file (C:\work\cricket\PSL\1128849.json)... PSL20180320PZQG
# Save match file (C:\work\cricket\PSL\1128850.json)... PSL20180321KKPZ
# Save match file (C:\work\cricket\PSL\1128851.json)... PSL20180325IUPZ
# Save match file (C:\work\cricket\PSL\1168820.json)... PSL20190214IULQ
# Save match file (C:\work\cricket\PSL\1168821.json)... PSL20190215KKMS
# Save match file (C:\work\cricket\PSL\1168822.json)... PSL20190215PZQG
# Save match file (C:\work\cricket\PSL\1168823.json)... PSL20190216IUMS
# Save match file (C:\work\cricket\PSL\1168824.json)... PSL20190216KKLQ
# Save match file (C:\work\cricket\PSL\1168825.json)... PSL20190217IUQG
# Save match file (C:\work\cricket\PSL\1168826.json)... PSL20190217LQPZ
# Save match file (C:\work\cricket\PSL\1168827.json)... PSL20190220MSQG
# Save match file (C:\work\cricket\PSL\1168828.json)... PSL20190221KKPZ
# Save match file (C:\work\cricket\PSL\1168829.json)... PSL20190222LQMS
# Save match file (C:\work\cricket\PSL\1168830.json)... PSL20190222IUPZ
# Save match file (C:\work\cricket\PSL\1168831.json)... PSL20190223LQQG
# Save match file (C:\work\cricket\PSL\1168832.json)... PSL20190223IUKK
# Save match file (C:\work\cricket\PSL\1168833.json)... PSL20190224MSPZ
# Save match file (C:\work\cricket\PSL\1168834.json)... PSL20190224KKQG
# Save match file (C:\work\cricket\PSL\1168835.json)... PSL20190226IUMS
# Save match file (C:\work\cricket\PSL\1168836.json)... PSL20190227LQQG
# Save match file (C:\work\cricket\PSL\1168837.json)... PSL20190227IUKK
# Save match file (C:\work\cricket\PSL\1168838.json)... PSL20190228MSPZ
# Save match file (C:\work\cricket\PSL\1168839.json)... PSL20190228KKLQ
# Save match file (C:\work\cricket\PSL\1168840.json)... PSL20190301IUPZ
# Save match file (C:\work\cricket\PSL\1168841.json)... PSL20190301MSQG
# Save match file (C:\work\cricket\PSL\1168842.json)... PSL20190304PZQG
# Save match file (C:\work\cricket\PSL\1168843.json)... PSL20190304KKMS
# Save match file (C:\work\cricket\PSL\1168844.json)... PSL20190305LQPZ
# Save match file (C:\work\cricket\PSL\1168845.json)... PSL20190305IUQG
# Save match file (C:\work\cricket\PSL\1168846.json)... PSL20190311KKPZ
# Save match file (C:\work\cricket\PSL\1168847.json)... PSL20190309LQIU
# Save match file (C:\work\cricket\PSL\1168848.json)... PSL20190310KKQG
# Save match file (C:\work\cricket\PSL\1168849.json)... PSL20190311LQMS
# Save match file (C:\work\cricket\PSL\1168850.json)... PSL20190314IUKK
# Save match file (C:\work\cricket\PSL\1168851.json)... PSL20190313PZQG
# Save match file (C:\work\cricket\PSL\1168852.json)... PSL20190315IUPZ
# Save match file (C:\work\cricket\PSL\1168853.json)... PSL20190317QGPZ
# Save match file (C:\work\cricket\PSL\1211642.json)... PSL20200220IUQG
# Save match file (C:\work\cricket\PSL\1211643.json)... PSL20200221KKPZ
# Save match file (C:\work\cricket\PSL\1211644.json)... PSL20200221LQMS
# Save match file (C:\work\cricket\PSL\1211645.json)... PSL20200222PZQG
# Save match file (C:\work\cricket\PSL\1211646.json)... PSL20200222IUMS
# Save match file (C:\work\cricket\PSL\1211647.json)... PSL20200223KKQG
# Save match file (C:\work\cricket\PSL\1211648.json)... PSL20200223LQIU
# Save match file (C:\work\cricket\PSL\1211649.json)... PSL20200226MSPZ
# Save match file (C:\work\cricket\PSL\1211650.json)... PSL20200227IUQG
# Save match file (C:\work\cricket\PSL\1211651.json)... PSL20200228MSKK
# Save match file (C:\work\cricket\PSL\1211652.json)... PSL20200228LQPZ
# Save match file (C:\work\cricket\PSL\1211653.json)... PSL20200229MSQG
# Save match file (C:\work\cricket\PSL\1211655.json)... PSL20200301IUKK
# Save match file (C:\work\cricket\PSL\1211656.json)... PSL20200302KKPZ
# Save match file (C:\work\cricket\PSL\1211657.json)... PSL20200303LQQG
# Save match file (C:\work\cricket\PSL\1211658.json)... PSL20200304LQIU
# Save match file (C:\work\cricket\PSL\1211659.json)... PSL20200305PZQG
# Save match file (C:\work\cricket\PSL\1211660.json)... PSL20200306KKMS
# Save match file (C:\work\cricket\PSL\1211661.json)... PSL20200307IUPZ
# Save match file (C:\work\cricket\PSL\1211662.json)... PSL20200307LQQG
# Save match file (C:\work\cricket\PSL\1211663.json)... PSL20200308IUMS
# Save match file (C:\work\cricket\PSL\1211664.json)... PSL20200308LQKK
# Save match file (C:\work\cricket\PSL\1211665.json)... PSL20200310LQPZ
# Save match file (C:\work\cricket\PSL\1211667.json)... PSL20200312KKLQ
# Save match file (C:\work\cricket\PSL\1211668.json)... PSL20200313MSPZ
# Save match file (C:\work\cricket\PSL\1211669.json)... PSL20200314KKIU
# Save match file (C:\work\cricket\PSL\1211670.json)... PSL20200315LQMS
# Save match file (C:\work\cricket\PSL\1211671.json)... PSL20200315KKQG
# Save match file (C:\work\cricket\PSL\1211672.json)... PSL20201114MSKK
# Save match file (C:\work\cricket\PSL\1211673.json)... PSL20201114PZLQ
# Save match file (C:\work\cricket\PSL\1211675.json)... PSL20201115LQMS
# Save match file (C:\work\cricket\PSL\1231146.json)... PSL20201117LQKK
# Save match file (C:\work\cricket\PSL\1247011.json)... PSL20210220QGKK
# Save match file (C:\work\cricket\PSL\1247012.json)... PSL20210221PZLQ
# Save match file (C:\work\cricket\PSL\1247013.json)... PSL20210221MSIU
# Save match file (C:\work\cricket\PSL\1247014.json)... PSL20210222QGLQ
# Save match file (C:\work\cricket\PSL\1247015.json)... PSL20210223MSPZ
# Save match file (C:\work\cricket\PSL\1247016.json)... PSL20210224KKIU
# Save match file (C:\work\cricket\PSL\1247017.json)... PSL20210226LQMS
# Save match file (C:\work\cricket\PSL\1247018.json)... PSL20210226QGPZ
# Save match file (C:\work\cricket\PSL\1247019.json)... PSL20210227MSKK
# Save match file (C:\work\cricket\PSL\1247020.json)... PSL20210227IUPZ
# Save match file (C:\work\cricket\PSL\1247021.json)... PSL20210228KKLQ
# Save match file (C:\work\cricket\PSL\1247022.json)... PSL20210302QGIU
# Save match file (C:\work\cricket\PSL\1247023.json)... PSL20210303PZKK
# Save match file (C:\work\cricket\PSL\1247024.json)... PSL20210303QGMS
# Save match file (C:\work\cricket\PSL\1247025.json)... PSL20210610MSKK
# Save match file (C:\work\cricket\PSL\1247026.json)... PSL20210610LQPZ
# Save match file (C:\work\cricket\PSL\1247027.json)... PSL20210609IULQ
# Save match file (C:\work\cricket\PSL\1247028.json)... PSL20210611QGIU
# Save match file (C:\work\cricket\PSL\1247029.json)... PSL20210613IULQ
# Save match file (C:\work\cricket\PSL\1247030.json)... PSL20210612PZQG
# Save match file (C:\work\cricket\PSL\1247031.json)... PSL20210613PZMS
# Save match file (C:\work\cricket\PSL\1247032.json)... PSL20210614KKIU
# Save match file (C:\work\cricket\PSL\1247033.json)... PSL20210615QGLQ
# Save match file (C:\work\cricket\PSL\1247034.json)... PSL20210615KKPZ
# Save match file (C:\work\cricket\PSL\1247035.json)... PSL20210616MSQG
# Save match file (C:\work\cricket\PSL\1247036.json)... PSL20210617IUPZ
# Save match file (C:\work\cricket\PSL\1247037.json)... PSL20210617KKLQ
# Save match file (C:\work\cricket\PSL\1247038.json)... PSL20210618MSLQ
# Save match file (C:\work\cricket\PSL\1247039.json)... PSL20210619KKQG
# Save match file (C:\work\cricket\PSL\1247040.json)... PSL20210619MSIU
# Save match file (C:\work\cricket\PSL\1247041.json)... PSL20210621MSIU
# Save match file (C:\work\cricket\PSL\1247042.json)... PSL20210621KKPZ
# Save match file (C:\work\cricket\PSL\1247043.json)... PSL20210622IUPZ
# Save match file (C:\work\cricket\PSL\1247044.json)... PSL20210624MSPZ
# Save match file (C:\work\cricket\PSL\1293000.json)... PSL20220127KKMS
# Save match file (C:\work\cricket\PSL\1293001.json)... PSL20220128QGPZ
# Save match file (C:\work\cricket\PSL\1293002.json)... PSL20220129LQMS
# Save match file (C:\work\cricket\PSL\1293003.json)... PSL20220129KKQG
# Save match file (C:\work\cricket\PSL\1293004.json)... PSL20220130PZIU
# Save match file (C:\work\cricket\PSL\1293005.json)... PSL20220130KKLQ
# Save match file (C:\work\cricket\PSL\1293006.json)... PSL20220131MSQG
# Save match file (C:\work\cricket\PSL\1293007.json)... PSL20220201MSIU
# Save match file (C:\work\cricket\PSL\1293008.json)... PSL20220202LQPZ
# Save match file (C:\work\cricket\PSL\1293009.json)... PSL20220203IUQG
# Save match file (C:\work\cricket\PSL\1293010.json)... PSL20220204PZKK
# Save match file (C:\work\cricket\PSL\1293011.json)... PSL20220205LQIU
# Save match file (C:\work\cricket\PSL\1293012.json)... PSL20220205MSPZ
# Save match file (C:\work\cricket\PSL\1293013.json)... PSL20220206IUKK
# Save match file (C:\work\cricket\PSL\1293014.json)... PSL20220207LQQG
# Save match file (C:\work\cricket\PSL\1293015.json)... PSL20220210MSPZ
# Save match file (C:\work\cricket\PSL\1293016.json)... PSL20220211LQMS
# Save match file (C:\work\cricket\PSL\1293017.json)... PSL20220212IUQG
# Save match file (C:\work\cricket\PSL\1293018.json)... PSL20220213PZKK
# Save match file (C:\work\cricket\PSL\1293019.json)... PSL20220213QGLQ
# Save match file (C:\work\cricket\PSL\1293020.json)... PSL20220214IUKK
# Save match file (C:\work\cricket\PSL\1293021.json)... PSL20220215PZQG
# Save match file (C:\work\cricket\PSL\1293022.json)... PSL20220216KKMS
# Save match file (C:\work\cricket\PSL\1293023.json)... PSL20220217PZIU
# Save match file (C:\work\cricket\PSL\1293024.json)... PSL20220218MSQG
# Save match file (C:\work\cricket\PSL\1293025.json)... PSL20220218KKLQ
# Save match file (C:\work\cricket\PSL\1293026.json)... PSL20220219LQIU
# Save match file (C:\work\cricket\PSL\1293027.json)... PSL20220220QGKK
# Save match file (C:\work\cricket\PSL\1293028.json)... PSL20220220IUMS
# Save match file (C:\work\cricket\PSL\1293029.json)... PSL20220221PZLQ
# Save match file (C:\work\cricket\PSL\1293030.json)... PSL20220223MSLQ
# Save match file (C:\work\cricket\PSL\1293031.json)... PSL20220224PZIU
# Save match file (C:\work\cricket\PSL\1293032.json)... PSL20220225LQIU
# Save match file (C:\work\cricket\PSL\1293033.json)... PSL20220227LQMS
# Save match file (C:\work\cricket\PSL\1354924.json)... PSL20230213LQMS
# Save match file (C:\work\cricket\PSL\1354925.json)... PSL20230214PZKK
# Save match file (C:\work\cricket\PSL\1354926.json)... PSL20230215QGMS
# Save match file (C:\work\cricket\PSL\1354927.json)... PSL20230216KKIU
# Save match file (C:\work\cricket\PSL\1354928.json)... PSL20230217MSPZ
# Save match file (C:\work\cricket\PSL\1354929.json)... PSL20230218QGKK
# Save match file (C:\work\cricket\PSL\1354930.json)... PSL20230219MSIU
# Save match file (C:\work\cricket\PSL\1354931.json)... PSL20230219KKLQ
# Save match file (C:\work\cricket\PSL\1354932.json)... PSL20230220QGPZ
# Save match file (C:\work\cricket\PSL\1354933.json)... PSL20230221LQQG
# Save match file (C:\work\cricket\PSL\1354934.json)... PSL20230222MSKK
# Save match file (C:\work\cricket\PSL\1354935.json)... PSL20230223PZIU
# Save match file (C:\work\cricket\PSL\1354936.json)... PSL20230224IUQG
# Save match file (C:\work\cricket\PSL\1354937.json)... PSL20230226KKMS
# Save match file (C:\work\cricket\PSL\1354938.json)... PSL20230226LQPZ
# Save match file (C:\work\cricket\PSL\1354939.json)... PSL20230227LQIU
# Save match file (C:\work\cricket\PSL\1354940.json)... PSL20230301PZKK
# Save match file (C:\work\cricket\PSL\1354941.json)... PSL20230302LQQG
# Save match file (C:\work\cricket\PSL\1354942.json)... PSL20230303KKIU
# Save match file (C:\work\cricket\PSL\1354943.json)... PSL20230304LQMS
# Save match file (C:\work\cricket\PSL\1354944.json)... PSL20230305QGIU
# Save match file (C:\work\cricket\PSL\1354945.json)... PSL20230306KKQG
# Save match file (C:\work\cricket\PSL\1354946.json)... PSL20230307PZLQ
# Save match file (C:\work\cricket\PSL\1354947.json)... PSL20230307MSIU
# Save match file (C:\work\cricket\PSL\1354948.json)... PSL20230308PZQG
# Save match file (C:\work\cricket\PSL\1354949.json)... PSL20230309LQIU
# Save match file (C:\work\cricket\PSL\1354950.json)... PSL20230310PZMS
# Save match file (C:\work\cricket\PSL\1354951.json)... PSL20230311MSQG
# Save match file (C:\work\cricket\PSL\1354952.json)... PSL20230312PZIU
# Save match file (C:\work\cricket\PSL\1354953.json)... PSL20230312KKLQ
# Save match file (C:\work\cricket\PSL\1354954.json)... PSL20230315MSLQ
# Save match file (C:\work\cricket\PSL\1354955.json)... PSL20230316PZIU
# Save match file (C:\work\cricket\PSL\1354956.json)... PSL20230317PZLQ
# Save match file (C:\work\cricket\PSL\1354957.json)... PSL20230318LQMS
# Save match file (C:\work\cricket\PSL\1416472.json)... PSL20240217LQIU
# Save match file (C:\work\cricket\PSL\1416473.json)... PSL20240218QGPZ
# Save match file (C:\work\cricket\PSL\1416474.json)... PSL20240218MSKK
# Save match file (C:\work\cricket\PSL\1416475.json)... PSL20240219LQQG
# Save match file (C:\work\cricket\PSL\1416476.json)... PSL20240220IUMS
# Save match file (C:\work\cricket\PSL\1416477.json)... PSL20240221PZKK
# Save match file (C:\work\cricket\PSL\1416478.json)... PSL20240221LQMS
# Save match file (C:\work\cricket\PSL\1416479.json)... PSL20240222IUQG
# Save match file (C:\work\cricket\PSL\1416480.json)... PSL20240223PZMS
# Save match file (C:\work\cricket\PSL\1416481.json)... PSL20240224LQKK
# Save match file (C:\work\cricket\PSL\1416482.json)... PSL20240225MSQG
# Save match file (C:\work\cricket\PSL\1416483.json)... PSL20240225PZLQ
# Save match file (C:\work\cricket\PSL\1416484.json)... PSL20240226PZIU
# Save match file (C:\work\cricket\PSL\1416485.json)... PSL20240227MSLQ
# Save match file (C:\work\cricket\PSL\1416486.json)... PSL20240228KKIU
# Save match file (C:\work\cricket\PSL\1416487.json)... PSL20240229KKQG
# Save match file (C:\work\cricket\PSL\1416490.json)... PSL20240303MSKK
# Save match file (C:\work\cricket\PSL\1416491.json)... PSL20240304IUPZ
# Save match file (C:\work\cricket\PSL\1416492.json)... PSL20240305PZMS
# Save match file (C:\work\cricket\PSL\1416493.json)... PSL20240306QGKK
# Save match file (C:\work\cricket\PSL\1416494.json)... PSL20240306LQIU
# Save match file (C:\work\cricket\PSL\1416495.json)... PSL20240307KKIU
# Save match file (C:\work\cricket\PSL\1416496.json)... PSL20240308PZQG
# Save match file (C:\work\cricket\PSL\1416497.json)... PSL20240309LQKK
# Save match file (C:\work\cricket\PSL\1416498.json)... PSL20240310MSIU
# Save match file (C:\work\cricket\PSL\1416499.json)... PSL20240310LQQG
# Save match file (C:\work\cricket\PSL\1416500.json)... PSL20240311PZKK
# Save match file (C:\work\cricket\PSL\1416501.json)... PSL20240312MSQG
# Save match file (C:\work\cricket\PSL\1416502.json)... PSL20240314PZMS
# Save match file (C:\work\cricket\PSL\1416503.json)... PSL20240315IUQG
# Save match file (C:\work\cricket\PSL\1416504.json)... PSL20240316PZIU
# Save match file (C:\work\cricket\PSL\1416505.json)... PSL20240318MSIU
# Save match file (C:\work\cricket\PSL\959175.json)... PSL20160204IUQG
# Save match file (C:\work\cricket\PSL\959177.json)... PSL20160205LQKK
# Save match file (C:\work\cricket\PSL\959179.json)... PSL20160205PZIU
# Save match file (C:\work\cricket\PSL\959181.json)... PSL20160206KKQG
# Save match file (C:\work\cricket\PSL\959183.json)... PSL20160206LQPZ
# Save match file (C:\work\cricket\PSL\959185.json)... PSL20160207IUKK
# Save match file (C:\work\cricket\PSL\959187.json)... PSL20160207PZQG
# Save match file (C:\work\cricket\PSL\959189.json)... PSL20160208LQQG
# Save match file (C:\work\cricket\PSL\959191.json)... PSL20160210LQIU
# Save match file (C:\work\cricket\PSL\959195.json)... PSL20160211IUQG
# Save match file (C:\work\cricket\PSL\959197.json)... PSL20160212KKLQ
# Save match file (C:\work\cricket\PSL\959199.json)... PSL20160212IUPZ
# Save match file (C:\work\cricket\PSL\959201.json)... PSL20160213KKQG
# Save match file (C:\work\cricket\PSL\959203.json)... PSL20160213LQPZ
# Save match file (C:\work\cricket\PSL\959205.json)... PSL20160214KKIU
# Save match file (C:\work\cricket\PSL\959207.json)... PSL20160214QGPZ
# Save match file (C:\work\cricket\PSL\959209.json)... PSL20160216LQQG
# Save match file (C:\work\cricket\PSL\959211.json)... PSL20160217KKPZ
# Save match file (C:\work\cricket\PSL\959213.json)... PSL20160217LQIU
# Save match file (C:\work\cricket\PSL\959215.json)... PSL20160219QGPZ
# Save match file (C:\work\cricket\PSL\959217.json)... PSL20160220KKIU
# Save match file (C:\work\cricket\PSL\959219.json)... PSL20160221IUPZ
# Save match file (C:\work\cricket\PSL\959221.json)... PSL20160223QGIU
# Save match file (C:\work\cricket\PSL\match.json)... PSL20160204IUQG
